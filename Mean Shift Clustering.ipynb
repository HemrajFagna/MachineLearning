# %%
import numpy as np
from sklearn.cluster import MeanShift
from sklearn.datasets.samples_generator import make_blobs
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import style
style.use("ggplot")

centers = [[1,1,1],[5,5,5],[3,10,10]] #initialization of centers, we have to initialize with some points

X, _ = make_blobs(n_samples = 100, centers = centers, cluster_std = 1.5)

ms = MeanShift()
ms.fit(X)
labels = ms.labels_
cluster_centers = ms.cluster_centers_

print(cluster_centers)
n_clusters_ = len(np.unique(labels))
print("Number of estimated clusters:", n_clusters_)

colors = 10*['r','g','b','c','k','y','m']
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for i in range(len(X)):
    ax.scatter(X[i][0], X[i][1], X[i][2], c=colors[labels[i]], marker='o')

ax.scatter(cluster_centers[:,0],cluster_centers[:,1],cluster_centers[:,2],
            marker="x",color='k', s=150, linewidths = 5, zorder=10)

plt.show()
# Out:
# [[ 3.1458301   3.29711826  2.98541184]
#  [ 2.5013923  10.16252742 10.15865821]]
# Number of estimated clusters: 2

# %%
# mean shift on titanic dataset
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
from sklearn.cluster import MeanShift
from sklearn import preprocessing
import pandas as pd

df = pd.read_excel("C:/Users/Dell/Desktop/Python/titanic.xls")
original_df = pd.DataFrame.copy(df)
df.drop(['body','name'],1, inplace= True)
df.convert_objects(convert_numeric=True)
df.fillna(0, inplace=True)
#df.head()

def handle_non_numeric_data(df):
    columns = df.columns.values
    for column in columns:
        text_digit_vals = { }
        def convert_to_int(val):
            return text_digit_vals[val]
        
        if df[column].dtype != np.int64 and df[column].dtype != np.float64:
            column_content = df[column].values.tolist()
            unique_elements = set(column_content)
            x = 0
            for unique in unique_elements:
                if unique not in text_digit_vals:
                    text_digit_vals[unique] = x
                    x += 1
        
            df[column] = list(map(convert_to_int, df[column]))
    return df


df = handle_non_numeric_data(df)
#df[:50]

X = np.array(df.drop(['survived'],1).astype(float))
X = preprocessing.scale(X) # without this accu is 50%
y = np.array(df['survived'])

clf = MeanShift()
clf.fit(X)
# Out:
# E:\Program Files\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   del sys.path[0]
# MeanShift(bandwidth=None, bin_seeding=False, cluster_all=True, min_bin_freq=1,
#      n_jobs=1, seeds=None)

# %%
labels = clf.labels_
cluster_centers = clf.cluster_centers_
original_df['cluster_group'] = np.nan

for i in range(len(X)):
    original_df['cluster_group'].iloc[i] = labels[i]

n_clusters = len(np.unique(labels))
survival_rates = {}

for i in range(n_clusters):
    temp_df = original_df[ (original_df['cluster_group'] == float(i)) ]
    survival_cluster = temp_df[(temp_df['survived']==1)]
    survival_rate = len(survival_cluster)/ len(temp_df)
    survival_rates[i] = survival_rate
print(survival_rates)
# Out:
# E:\Program Files\Anaconda3\lib\site-packages\pandas\core\indexing.py:194: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# {0: 0.38351822503961963, 1: 0.045454545454545456, 2: 0.9333333333333333, 3: 0.1}

# %%
original_df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body  cluster_group
# count  1308.000000  121.000000    1309.000000
# mean     33.295479  160.809917       0.062643
# std      51.758668   97.696922       0.357171
# min       0.000000    1.000000       0.000000
# 25%       7.895800   72.000000       0.000000
# 50%      14.454200  155.000000       0.000000
# 75%      31.275000  256.000000       0.000000
# max     512.329200  328.000000       3.000000

# %%
original_df[(original_df['cluster_group']==0)]
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12         1         1                      Aubart, Mme. Leontine Pauline
# 13         1         1                       Barber, Miss. Ellen "Nellie"
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 15         1         0                                Baumann, Mr. John D
# 16         1         0                           Baxter, Mr. Quigg Edmond
# 18         1         1                              Bazzani, Miss. Albina
# 19         1         0                               Beattie, Mr. Thomson
# 20         1         1                      Beckwith, Mr. Richard Leonard
# 21         1         1   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 22         1         1                              Behr, Mr. Karl Howell
# 23         1         1                              Bidois, Miss. Rosalie
# 24         1         1                                  Bird, Miss. Ellen
# 25         1         0                                Birnbaum, Mr. Jakob
# 26         1         1                            Bishop, Mr. Dickinson H
# 27         1         1            Bishop, Mrs. Dickinson H (Helen Walton)
# 28         1         1                             Bissette, Miss. Amelia
# 29         1         1          Bjornstrom-Steffansson, Mr. Mauritz Hakan
# 30         1         0                       Blackwell, Mr. Stephen Weart
# ...      ...       ...                                                ...
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1280       3         0                                    Vovk, Mr. Janko
# 1281       3         0                               Waelens, Mr. Achille
# 1282       3         0                                Ware, Mr. Frederick
# 1283       3         0                        Warren, Mr. Charles William
# 1284       3         0                                  Webber, Mr. James
# 1285       3         0                                Wenzel, Mr. Linhart
# 1286       3         1    Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1287       3         0                   Widegren, Mr. Carl/Charles Peter
# 1288       3         0                          Wiklund, Mr. Jakob Alfred
# 1289       3         0                            Wiklund, Mr. Karl Johan
# 1290       3         1                   Wilkes, Mrs. James (Ellen Needs)
# 1291       3         0                   Willer, Mr. Aaron ("Abi Weller")
# 1292       3         0                                 Willey, Mr. Edward
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1294       3         0                               Williams, Mr. Leslie
# 1295       3         0                                Windelov, Mr. Einar
# 1296       3         0                                   Wirz, Mr. Albert
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1298       3         0                          Wittevrongel, Mr. Camille
# 1299       3         0                                Yasbeck, Mr. Antoni
# 1300       3         1            Yasbeck, Mrs. Antoni (Selini Alexander)
# 1301       3         0                               Youseff, Mr. Gerious
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1304       3         0                               Zabour, Miss. Hileni
# 1305       3         0                              Zabour, Miss. Thamine
# 1306       3         0                          Zakarian, Mr. Mapriededer
# 1307       3         0                                Zakarian, Mr. Ortin
# 1308       3         0                                 Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch            ticket      fare    cabin  \
# 0     female  29.0000      0      0             24160  211.3375       B5
# 1       male   0.9167      1      2            113781  151.5500  C22 C26
# 2     female   2.0000      1      2            113781  151.5500  C22 C26
# 3       male  30.0000      1      2            113781  151.5500  C22 C26
# 4     female  25.0000      1      2            113781  151.5500  C22 C26
# 5       male  48.0000      0      0             19952   26.5500      E12
# 6     female  63.0000      1      0             13502   77.9583       D7
# 7       male  39.0000      0      0            112050    0.0000      A36
# 8     female  53.0000      2      0             11769   51.4792     C101
# 9       male  71.0000      0      0          PC 17609   49.5042      NaN
# 10      male  47.0000      1      0          PC 17757  227.5250  C62 C64
# 11    female  18.0000      1      0          PC 17757  227.5250  C62 C64
# 12    female  24.0000      0      0          PC 17477   69.3000      B35
# 13    female  26.0000      0      0             19877   78.8500      NaN
# 14      male  80.0000      0      0             27042   30.0000      A23
# 15      male      NaN      0      0          PC 17318   25.9250      NaN
# 16      male  24.0000      0      1          PC 17558  247.5208  B58 B60
# 18    female  32.0000      0      0             11813   76.2917      D15
# 19      male  36.0000      0      0             13050   75.2417       C6
# 20      male  37.0000      1      1             11751   52.5542      D35
# 21    female  47.0000      1      1             11751   52.5542      D35
# 22      male  26.0000      0      0            111369   30.0000     C148
# 23    female  42.0000      0      0          PC 17757  227.5250      NaN
# 24    female  29.0000      0      0          PC 17483  221.7792      C97
# 25      male  25.0000      0      0             13905   26.0000      NaN
# 26      male  25.0000      1      0             11967   91.0792      B49
# 27    female  19.0000      1      0             11967   91.0792      B49
# 28    female  35.0000      0      0          PC 17760  135.6333      C99
# 29      male  28.0000      0      0            110564   26.5500      C52
# 30      male  45.0000      0      0            113784   35.5000        T
# ...      ...      ...    ...    ...               ...       ...      ...
# 1279  female  14.0000      0      0            350406    7.8542      NaN
# 1280    male  22.0000      0      0            349252    7.8958      NaN
# 1281    male  22.0000      0      0            345767    9.0000      NaN
# 1282    male      NaN      0      0            359309    8.0500      NaN
# 1283    male      NaN      0      0        C.A. 49867    7.5500      NaN
# 1284    male      NaN      0      0  SOTON/OQ 3101316    8.0500      NaN
# 1285    male  32.5000      0      0            345775    9.5000      NaN
# 1286  female  38.0000      0      0              2688    7.2292      NaN
# 1287    male  51.0000      0      0            347064    7.7500      NaN
# 1288    male  18.0000      1      0           3101267    6.4958      NaN
# 1289    male  21.0000      1      0           3101266    6.4958      NaN
# 1290  female  47.0000      1      0            363272    7.0000      NaN
# 1291    male      NaN      0      0              3410    8.7125      NaN
# 1292    male      NaN      0      0     S.O./P.P. 751    7.5500      NaN
# 1293    male      NaN      0      0          A/5 2466    8.0500      NaN
# 1294    male  28.5000      0      0             54636   16.1000      NaN
# 1295    male  21.0000      0      0  SOTON/OQ 3101317    7.2500      NaN
# 1296    male  27.0000      0      0            315154    8.6625      NaN
# 1297    male      NaN      0      0        A/4. 34244    7.2500      NaN
# 1298    male  36.0000      0      0            345771    9.5000      NaN
# 1299    male  27.0000      1      0              2659   14.4542      NaN
# 1300  female  15.0000      1      0              2659   14.4542      NaN
# 1301    male  45.5000      0      0              2628    7.2250      NaN
# 1302    male      NaN      0      0              2647    7.2250      NaN
# 1303    male      NaN      0      0              2627   14.4583      NaN
# 1304  female  14.5000      1      0              2665   14.4542      NaN
# 1305  female      NaN      1      0              2665   14.4542      NaN
# 1306    male  26.5000      0      0              2656    7.2250      NaN
# 1307    male  27.0000      0      0              2670    7.2250      NaN
# 1308    male  29.0000      0      0            315082    7.8750      NaN
#
#      embarked boat   body                           home.dest  cluster_group
# 0           S    2    NaN                        St Louis, MO            0.0
# 1           S   11    NaN     Montreal, PQ / Chesterville, ON            0.0
# 2           S  NaN    NaN     Montreal, PQ / Chesterville, ON            0.0
# 3           S  NaN  135.0     Montreal, PQ / Chesterville, ON            0.0
# 4           S  NaN    NaN     Montreal, PQ / Chesterville, ON            0.0
# 5           S    3    NaN                        New York, NY            0.0
# 6           S   10    NaN                          Hudson, NY            0.0
# 7           S  NaN    NaN                         Belfast, NI            0.0
# 8           S    D    NaN                 Bayside, Queens, NY            0.0
# 9           C  NaN   22.0                 Montevideo, Uruguay            0.0
# 10          C  NaN  124.0                        New York, NY            0.0
# 11          C    4    NaN                        New York, NY            0.0
# 12          C    9    NaN                       Paris, France            0.0
# 13          S    6    NaN                                 NaN            0.0
# 14          S    B    NaN                       Hessle, Yorks            0.0
# 15          S  NaN    NaN                        New York, NY            0.0
# 16          C  NaN    NaN                        Montreal, PQ            0.0
# 18          C    8    NaN                                 NaN            0.0
# 19          C    A    NaN                        Winnipeg, MN            0.0
# 20          S    5    NaN                        New York, NY            0.0
# 21          S    5    NaN                        New York, NY            0.0
# 22          C    5    NaN                        New York, NY            0.0
# 23          C    4    NaN                                 NaN            0.0
# 24          S    8    NaN                                 NaN            0.0
# 25          C  NaN  148.0                   San Francisco, CA            0.0
# 26          C    7    NaN                        Dowagiac, MI            0.0
# 27          C    7    NaN                        Dowagiac, MI            0.0
# 28          S    8    NaN                                 NaN            0.0
# 29          S    D    NaN  Stockholm, Sweden / Washington, DC            0.0
# 30          S  NaN    NaN                         Trenton, NJ            0.0
# ...       ...  ...    ...                                 ...            ...
# 1279        S  NaN    NaN                                 NaN            0.0
# 1280        S  NaN    NaN                                 NaN            0.0
# 1281        S  NaN    NaN      Antwerp, Belgium / Stanton, OH            0.0
# 1282        S  NaN    NaN                                 NaN            0.0
# 1283        S  NaN    NaN                                 NaN            0.0
# 1284        S  NaN    NaN                                 NaN            0.0
# 1285        S  NaN  298.0                                 NaN            0.0
# 1286        C    C    NaN                                 NaN            0.0
# 1287        S  NaN    NaN                                 NaN            0.0
# 1288        S  NaN  314.0                                 NaN            0.0
# 1289        S  NaN    NaN                                 NaN            0.0
# 1290        S  NaN    NaN                                 NaN            0.0
# 1291        S  NaN    NaN                                 NaN            0.0
# 1292        S  NaN    NaN                                 NaN            0.0
# 1293        S  NaN    NaN                                 NaN            0.0
# 1294        S  NaN   14.0                                 NaN            0.0
# 1295        S  NaN    NaN                                 NaN            0.0
# 1296        S  NaN  131.0                                 NaN            0.0
# 1297        S  NaN    NaN                                 NaN            0.0
# 1298        S  NaN    NaN                                 NaN            0.0
# 1299        C    C    NaN                                 NaN            0.0
# 1300        C  NaN    NaN                                 NaN            0.0
# 1301        C  NaN  312.0                                 NaN            0.0
# 1302        C  NaN    NaN                                 NaN            0.0
# 1303        C  NaN    NaN                                 NaN            0.0
# 1304        C  NaN  328.0                                 NaN            0.0
# 1305        C  NaN    NaN                                 NaN            0.0
# 1306        C  NaN  304.0                                 NaN            0.0
# 1307        C  NaN    NaN                                 NaN            0.0
# 1308        S  NaN    NaN                                 NaN            0.0
#
# [1262 rows x 15 columns]

# %%
original_df[(original_df['cluster_group']==0)].describe()
# Out:
#             pclass     survived          age        sibsp       parch  \
# count  1262.000000  1262.000000  1009.000000  1262.000000  1262.00000
# mean      2.292393     0.383518    29.968451     0.395404     0.29794
# std       0.834005     0.486435    14.270147     0.725481     0.64584
# min       1.000000     0.000000     0.166700     0.000000     0.00000
# 25%       2.000000     0.000000    21.000000     0.000000     0.00000
# 50%       3.000000     0.000000    28.000000     0.000000     0.00000
# 75%       3.000000     1.000000    38.500000     1.000000     0.00000
# max       3.000000     1.000000    80.000000     4.000000     4.00000
#
#               fare        body  cluster_group
# count  1261.000000  118.000000         1262.0
# mean     29.399871  160.355932            0.0
# std      39.603488   97.339175            0.0
# min       0.000000    1.000000            0.0
# 25%       7.895800   72.750000            0.0
# 50%      13.775000  155.500000            0.0
# 75%      29.000000  255.750000            0.0
# max     263.000000  328.000000            0.0

# %%
original_df[(original_df['cluster_group']==1)]
# Out:
#       pclass  survived                                     name     sex   age  \
# 622        3         0  Andersson, Master. Sigvard Harald Elias    male   4.0
# 623        3         0       Andersson, Miss. Ebba Iris Alfrida  female   6.0
# 624        3         0        Andersson, Miss. Ellis Anna Maria  female   2.0
# 627        3         0     Andersson, Miss. Ingeborg Constanzia  female   9.0
# 628        3         0        Andersson, Miss. Sigrid Elisabeth  female  11.0
# 639        3         0              Asplund, Master. Carl Edgar    male   5.0
# 643        3         1           Asplund, Miss. Lillian Gertrud  female   5.0
# 825        3         0           Goodwin, Master. Harold Victor    male   9.0
# 826        3         0          Goodwin, Master. Sidney Leonard    male   1.0
# 827        3         0       Goodwin, Master. William Frederick    male  11.0
# 828        3         0              Goodwin, Miss. Jessie Allis  female  10.0
# 829        3         0               Goodwin, Miss. Lillian Amy  female  16.0
# 830        3         0              Goodwin, Mr. Charles Edward    male  14.0
# 1170       3         0               Sage, Master. Thomas Henry    male   NaN
# 1171       3         0              Sage, Master. William Henry    male  14.5
# 1172       3         0                          Sage, Miss. Ada  female   NaN
# 1173       3         0             Sage, Miss. Constance Gladys  female   NaN
# 1174       3         0        Sage, Miss. Dorothy Edith "Dolly"  female   NaN
# 1175       3         0                  Sage, Miss. Stella Anna  female   NaN
# 1176       3         0                 Sage, Mr. Douglas Bullen    male   NaN
# 1177       3         0                      Sage, Mr. Frederick    male   NaN
# 1178       3         0                 Sage, Mr. George John Jr    male   NaN
#
#       sibsp  parch    ticket     fare cabin embarked boat  body  \
# 622       4      2    347082  31.2750   NaN        S  NaN   NaN
# 623       4      2    347082  31.2750   NaN        S  NaN   NaN
# 624       4      2    347082  31.2750   NaN        S  NaN   NaN
# 627       4      2    347082  31.2750   NaN        S  NaN   NaN
# 628       4      2    347082  31.2750   NaN        S  NaN   NaN
# 639       4      2    347077  31.3875   NaN        S  NaN   NaN
# 643       4      2    347077  31.3875   NaN        S   15   NaN
# 825       5      2   CA 2144  46.9000   NaN        S  NaN   NaN
# 826       5      2   CA 2144  46.9000   NaN        S  NaN   NaN
# 827       5      2   CA 2144  46.9000   NaN        S  NaN   NaN
# 828       5      2   CA 2144  46.9000   NaN        S  NaN   NaN
# 829       5      2   CA 2144  46.9000   NaN        S  NaN   NaN
# 830       5      2   CA 2144  46.9000   NaN        S  NaN   NaN
# 1170      8      2  CA. 2343  69.5500   NaN        S  NaN   NaN
# 1171      8      2  CA. 2343  69.5500   NaN        S  NaN  67.0
# 1172      8      2  CA. 2343  69.5500   NaN        S  NaN   NaN
# 1173      8      2  CA. 2343  69.5500   NaN        S  NaN   NaN
# 1174      8      2  CA. 2343  69.5500   NaN        S  NaN   NaN
# 1175      8      2  CA. 2343  69.5500   NaN        S  NaN   NaN
# 1176      8      2  CA. 2343  69.5500   NaN        S  NaN   NaN
# 1177      8      2  CA. 2343  69.5500   NaN        S  NaN   NaN
# 1178      8      2  CA. 2343  69.5500   NaN        S  NaN   NaN
#
#                                  home.dest  cluster_group
# 622                    Sweden Winnipeg, MN            1.0
# 623                    Sweden Winnipeg, MN            1.0
# 624                    Sweden Winnipeg, MN            1.0
# 627                    Sweden Winnipeg, MN            1.0
# 628                    Sweden Winnipeg, MN            1.0
# 639                  Sweden  Worcester, MA            1.0
# 643                   Sweden Worcester, MA            1.0
# 825   Wiltshire, England Niagara Falls, NY            1.0
# 826   Wiltshire, England Niagara Falls, NY            1.0
# 827   Wiltshire, England Niagara Falls, NY            1.0
# 828   Wiltshire, England Niagara Falls, NY            1.0
# 829   Wiltshire, England Niagara Falls, NY            1.0
# 830   Wiltshire, England Niagara Falls, NY            1.0
# 1170                                   NaN            1.0
# 1171                                   NaN            1.0
# 1172                                   NaN            1.0
# 1173                                   NaN            1.0
# 1174                                   NaN            1.0
# 1175                                   NaN            1.0
# 1176                                   NaN            1.0
# 1177                                   NaN            1.0
# 1178                                   NaN            1.0

# %%
original_df[(original_df['cluster_group']==1)].describe()
# Out:
#        pclass   survived        age      sibsp  parch       fare  body  \
# count    22.0  22.000000  14.000000  22.000000   22.0  22.000000   1.0
# mean      3.0   0.045455   8.392857   5.909091    2.0  51.204545  67.0
# std       0.0   0.213201   4.699339   1.823369    0.0  16.778019   NaN
# min       3.0   0.000000   1.000000   4.000000    2.0  31.275000  67.0
# 25%       3.0   0.000000   5.000000   4.000000    2.0  31.387500  67.0
# 50%       3.0   0.000000   9.000000   5.000000    2.0  46.900000  67.0
# 75%       3.0   0.000000  11.000000   8.000000    2.0  69.550000  67.0
# max       3.0   1.000000  16.000000   8.000000    2.0  69.550000  67.0
#
#        cluster_group
# count           22.0
# mean             1.0
# std              0.0
# min              1.0
# 25%              1.0
# 50%              1.0
# 75%              1.0
# max              1.0

# %%
original_df[(original_df['cluster_group']==2)]
# Out:
#      pclass  survived                                               name  \
# 17        1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 35        1         1                           Bowen, Miss. Grace Scott
# 49        1         1                 Cardeza, Mr. Thomas Drake Martinez
# 50        1         1  Cardeza, Mrs. James Warburton Martinez (Charlo...
# 66        1         1                        Chaudanson, Miss. Victorine
# 111       1         1                     Fortune, Miss. Alice Elizabeth
# 112       1         1                         Fortune, Miss. Ethel Flora
# 113       1         1                         Fortune, Miss. Mabel Helen
# 115       1         0                                  Fortune, Mr. Mark
# 116       1         1                Fortune, Mrs. Mark (Mary McDougald)
# 183       1         1                             Lesurer, Mr. Gustave J
# 250       1         1                         Ryerson, Miss. Emily Borie
# 251       1         1              Ryerson, Miss. Susan Parker "Suzette"
# 253       1         1    Ryerson, Mrs. Arthur Larned (Emily Maria Borie)
# 302       1         1                                   Ward, Miss. Anna
#
#         sex   age  sibsp  parch    ticket      fare            cabin embarked  \
# 17   female  50.0      0      1  PC 17558  247.5208          B58 B60        C
# 35   female  45.0      0      0  PC 17608  262.3750              NaN        C
# 49     male  36.0      0      1  PC 17755  512.3292      B51 B53 B55        C
# 50   female  58.0      0      1  PC 17755  512.3292      B51 B53 B55        C
# 66   female  36.0      0      0  PC 17608  262.3750              B61        C
# 111  female  24.0      3      2     19950  263.0000      C23 C25 C27        S
# 112  female  28.0      3      2     19950  263.0000      C23 C25 C27        S
# 113  female  23.0      3      2     19950  263.0000      C23 C25 C27        S
# 115    male  64.0      1      4     19950  263.0000      C23 C25 C27        S
# 116  female  60.0      1      4     19950  263.0000      C23 C25 C27        S
# 183    male  35.0      0      0  PC 17755  512.3292             B101        C
# 250  female  18.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 251  female  21.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 253  female  48.0      1      3  PC 17608  262.3750  B57 B59 B63 B66        C
# 302  female  35.0      0      0  PC 17755  512.3292              NaN        C
#
#     boat  body                                       home.dest  cluster_group
# 17     6   NaN                                    Montreal, PQ            2.0
# 35     4   NaN                                 Cooperstown, NY            2.0
# 49     3   NaN  Austria-Hungary / Germantown, Philadelphia, PA            2.0
# 50     3   NaN                    Germantown, Philadelphia, PA            2.0
# 66     4   NaN                                             NaN            2.0
# 111   10   NaN                                    Winnipeg, MB            2.0
# 112   10   NaN                                    Winnipeg, MB            2.0
# 113   10   NaN                                    Winnipeg, MB            2.0
# 115  NaN   NaN                                    Winnipeg, MB            2.0
# 116   10   NaN                                    Winnipeg, MB            2.0
# 183    3   NaN                                             NaN            2.0
# 250    4   NaN                 Haverford, PA / Cooperstown, NY            2.0
# 251    4   NaN                 Haverford, PA / Cooperstown, NY            2.0
# 253    4   NaN                 Haverford, PA / Cooperstown, NY            2.0
# 302    3   NaN                                             NaN            2.0

# %%
original_df[(original_df['cluster_group']==2)].describe()
# Out:
#        pclass   survived        age      sibsp      parch        fare  body  \
# count    15.0  15.000000  15.000000  15.000000  15.000000   15.000000   0.0
# mean      1.0   0.933333  38.733333   1.066667   1.600000  328.247507   NaN
# std       0.0   0.258199  14.834644   1.222799   1.352247  114.966828   NaN
# min       1.0   0.000000  18.000000   0.000000   0.000000  247.520800   NaN
# 25%       1.0   1.000000  26.000000   0.000000   0.500000  262.375000   NaN
# 50%       1.0   1.000000  36.000000   1.000000   2.000000  263.000000   NaN
# 75%       1.0   1.000000  49.000000   2.000000   2.000000  387.664600   NaN
# max       1.0   1.000000  64.000000   3.000000   4.000000  512.329200   NaN
#
#        cluster_group
# count           15.0
# mean             2.0
# std              0.0
# min              2.0
# 25%              2.0
# 50%              2.0
# 75%              2.0
# max              2.0
